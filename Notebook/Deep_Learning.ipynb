# %% [markdown]
# <a href="https://colab.research.google.com/github/villafue/Capstone_2_MovieLens/blob/main/Notebook/Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading https://files.pythonhosted.org/packages/97/37/5d334adaf5ddd65da99fc65f6507e0e4599d092ba048f4302fe8775619e8/scikit-surprise-1.1.1.tar.gz (11.8MB)
#      |████████████████████████████████| 11.8MB 12.2MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.0.1)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.15.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-linux_x86_64.whl size=1617522 sha256=f4a53737630a6d3df3632d20863359ea698bf86a134e31a83cc398d5892ab8af
#   Stored in directory: /root/.cache/pip/wheels/78/9c/3d/41b419c9d2aff5b6e2b4c0fc8d25c538202834058f9ed110d0
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.1

# %%
import os
os.mkdir('/content/deep_learning')
print('Folder created!')
os.chdir('/content/deep_learning')
print('Files are in this folder!')
# Out:
# Folder created!
# Files are in this folder!

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu May  3 11:11:13 2018

@author: Frank
"""

from MovieLens import MovieLens
from RBMAlgorithm import RBMAlgorithm
from surprise import NormalPredictor
from Evaluator import Evaluator
from surprise.model_selection import GridSearchCV

import random
import numpy as np

def LoadMovieLensData():
    ml = MovieLens()
    print("Loading movie ratings...")
    data = ml.loadMovieLensLatestSmall()
    print("\nComputing movie popularity ranks so we can measure novelty later...")
    rankings = ml.getPopularityRanks()
    return (ml, data, rankings)

np.random.seed(0)
random.seed(0)

# Load up common data set for the recommender algorithms
(ml, evaluationData, rankings) = LoadMovieLensData()

print("Searching for best parameters...")
param_grid = {'hiddenDim': [20, 10], 'learningRate': [0.1, 0.01]}
gs = GridSearchCV(RBMAlgorithm, param_grid, measures=['rmse', 'mae'], cv=3)

gs.fit(evaluationData)

# best RMSE score
print("Best RMSE score attained: ", gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])

# Construct an Evaluator to, you know, evaluate them
evaluator = Evaluator(evaluationData, rankings)

params = gs.best_params['rmse']
RBMtuned = RBMAlgorithm(hiddenDim = params['hiddenDim'], learningRate = params['learningRate'])
evaluator.AddAlgorithm(RBMtuned, "RBM - Tuned")

RBMUntuned = RBMAlgorithm()
evaluator.AddAlgorithm(RBMUntuned, "RBM - Untuned")

# Just make random recommendations
Random = NormalPredictor()
evaluator.AddAlgorithm(Random, "Random")

# Fight!
evaluator.Evaluate(False)

evaluator.SampleTopNRecs(ml)
# Out:
# Loading movie ratings...
#
# Computing movie popularity ranks so we can measure novelty later...
# Searching for best parameters...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Best RMSE score attained:  1.2821153950414816
# {'hiddenDim': 20, 'learningRate': 0.1}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating  RBM - Tuned ...
# Evaluating accuracy...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Analysis complete.
# Evaluating  RBM - Untuned ...
# Evaluating accuracy...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Analysis complete.
# Evaluating  Random ...
# Evaluating accuracy...
# Analysis complete.
#
#
# Algorithm  RMSE       MAE
# RBM - Tuned 1.2807     1.0866
# RBM - Untuned 1.2815     1.0873
# Random     1.4219     1.1343
#
# Legend:
#
# RMSE:      Root Mean Squared Error. Lower values mean better accuracy.
# MAE:       Mean Absolute Error. Lower values mean better accuracy.
#
# Using recommender  RBM - Tuned
#
# Building recommendation model...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing recommendations...
#
# We recommend:
# The Machinist (2004) 2.7719195
# Green Mile, The (1999) 2.7711062
# Singin' in the Rain (1952) 2.7703302
# Harry Potter and the Deathly Hallows: Part 2 (2011) 2.769996
# Toy Story (1995) 2.7696166
# Princess Bride, The (1987) 2.7691798
# Departed, The (2006) 2.7688186
# Aladdin (1992) 2.7682323
# Good Will Hunting (1997) 2.7681637
# Lion King, The (1994) 2.7681575
#
# Using recommender  RBM - Untuned
#
# Building recommendation model...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing recommendations...
#
# We recommend:
# Life Less Ordinary, A (1997) 2.7870138
# Ernest Scared Stupid (1991) 2.7860386
# Dersu Uzala (1975) 2.7841265
# Samurai Rebellion (JÃ´i-uchi: HairyÃ´ tsuma shimatsu) (1967) 2.7836213
# Mummy, The (1959) 2.7830892
# Bedazzled (2000) 2.782961
# Paper Man (2009) 2.7824347
# GLOW: The Story of the Gorgeous Ladies of Wrestling (2012) 2.7823644
# Oculus (2013) 2.7818763
# Bagdad Cafe (Out of Rosenheim) (1987) 2.7814488
#
# Using recommender  Random
#
# Building recommendation model...
# Computing recommendations...
#
# We recommend:
# Bottle Rocket (1996) 5
# Three Musketeers, The (1993) 5
# Batman (1989) 5
# Mission: Impossible (1996) 5
# Space Jam (1996) 5
# She's the One (1996) 5
# Ghost and Mrs. Muir, The (1947) 5
# Three Caballeros, The (1945) 5
# Basic Instinct (1992) 5
# Duck Soup (1933) 5

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu May  3 11:11:13 2018

@author: Frank
"""

from MovieLens import MovieLens
from RBMAlgorithm import RBMAlgorithm
from surprise import NormalPredictor
from Evaluator import Evaluator
from surprise.model_selection import GridSearchCV

import random
import numpy as np

def LoadMovieLensData():
    ml = MovieLens()
    print("Loading movie ratings...")
    data = ml.loadMovieLensLatestSmall()
    print("\nComputing movie popularity ranks so we can measure novelty later...")
    rankings = ml.getPopularityRanks()
    return (ml, data, rankings)

np.random.seed(29)
random.seed(29)

# Load up common data set for the recommender algorithms
(ml, evaluationData, rankings) = LoadMovieLensData()

print("Searching for best parameters...")
param_grid = {'hiddenDim': [20, 30, 40], 'learningRate': [0.1, 0.15, 0.2]}
gs = GridSearchCV(RBMAlgorithm, param_grid, measures=['rmse', 'mae'], cv=5)

gs.fit(evaluationData)

# best RMSE score
print("Best RMSE score attained: ", gs.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])

# Construct an Evaluator to, you know, evaluate them
evaluator = Evaluator(evaluationData, rankings)

params = gs.best_params['rmse']
RBMtuned = RBMAlgorithm(hiddenDim = params['hiddenDim'], learningRate = params['learningRate'])
evaluator.AddAlgorithm(RBMtuned, "RBM - Tuned")

RBMUntuned = RBMAlgorithm()
evaluator.AddAlgorithm(RBMUntuned, "RBM - Untuned")

# Just make random recommendations
Random = NormalPredictor()
evaluator.AddAlgorithm(Random, "Random")

# Fight!
evaluator.Evaluate(True)

evaluator.SampleTopNRecs(ml)
# Out:
# Loading movie ratings...
#
# Computing movie popularity ranks so we can measure novelty later...
# Searching for best parameters...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Best RMSE score attained:  1.2809030528148386
# {'hiddenDim': 40, 'learningRate': 0.2}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating  RBM - Tuned ...
# Evaluating accuracy...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Evaluating top-N with leave-one-out...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing hit-rate and rank metrics...
# Computing recommendations with full data set...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Analyzing coverage, diversity, and novelty...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Analysis complete.
# Evaluating  RBM - Untuned ...
# Evaluating accuracy...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Evaluating top-N with leave-one-out...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing hit-rate and rank metrics...
# Computing recommendations with full data set...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Analyzing coverage, diversity, and novelty...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Analysis complete.
# Evaluating  Random ...
# Evaluating accuracy...
# Evaluating top-N with leave-one-out...
# Computing hit-rate and rank metrics...
# Computing recommendations with full data set...
# Analyzing coverage, diversity, and novelty...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Analysis complete.
#
#
# Algorithm  RMSE       MAE        HR         cHR        ARHR       Coverage   Diversity  Novelty
# RBM - Tuned 1.2797     1.0856     0.0230     0.0230     0.0089     0.0000     0.0574     965.0569
# RBM - Untuned 1.2815     1.0872     0.0016     0.0016     0.0002     0.0000     0.7377     4912.7415
# Random     1.4218     1.1346     0.0115     0.0115     0.0042     1.0000     0.0499     860.2303
#
# Legend:
#
# RMSE:      Root Mean Squared Error. Lower values mean better accuracy.
# MAE:       Mean Absolute Error. Lower values mean better accuracy.
# HR:        Hit Rate; how often we are able to recommend a left-out rating. Higher is better.
# cHR:       Cumulative Hit Rate; hit rate, confined to ratings above a certain threshold. Higher is better.
# ARHR:      Average Reciprocal Hit Rank - Hit rate that takes the ranking into account. Higher is better.
# Coverage:  Ratio of users for whom recommendations above a certain threshold exist. Higher is better.
# Diversity: 1-S, where S is the average similarity score between every possible pair of recommendations
#            for a given user. Higher means more diverse.
# Novelty:   Average popularity rank of recommended items. Higher means more novel.
#
# Using recommender  RBM - Tuned
#
# Building recommendation model...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing recommendations...
#
# We recommend:
# Departed, The (2006) 2.892468
# Howl's Moving Castle (Hauru no ugoku shiro) (2004) 2.8908362
# Fight Club (1999) 2.8869665
# Memento (2000) 2.8868942
# Inside Out (2015) 2.8860178
# Monsters, Inc. (2001) 2.8839574
# Spirited Away (Sen to Chihiro no kamikakushi) (2001) 2.8832886
# Finding Nemo (2003) 2.8820338
# Godfather, The (1972) 2.8793077
# How to Train Your Dragon (2010) 2.8788555
#
# Using recommender  RBM - Untuned
#
# Building recommendation model...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing recommendations...
#
# We recommend:
# My Dog Skip (1999) 2.7925565
# Coco Before Chanel (Coco avant Chanel) (2009) 2.789673
# Story of Women (Affaire de femmes, Une) (1988) 2.7859182
# Sunshine (1999) 2.7854161
# Music of the Heart (1999) 2.783457
# Four Christmases (2008) 2.7831357
# Chronicles of Narnia: The Voyage of the Dawn Treader, The (2010) 2.7824636
# Splash (1984) 2.7824612
# Doctor Strange (2016) 2.782002
# Natural Born Killers (1994) 2.7810924
#
# Using recommender  Random
#
# Building recommendation model...
# Computing recommendations...
#
# We recommend:
# Ed Wood (1994) 5
# Mrs. Doubtfire (1993) 5
# Batman (1989) 5
# Highlander (1986) 5
# Great Mouse Detective, The (1986) 5
# Rocketeer, The (1991) 5
# Willow (1988) 5
# Texas Chainsaw Massacre, The (1974) 5
# Superman II (1980) 5
# Frankenstein (1931) 5

# %% [markdown]
# Next, I'll run a GridSearch of AutoEncoder.
#
# Update: I tried running it and it timed out after about 18 hours. I'm running it again with less hyperparameters and with only 2 cross validations instead of 5.

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu May  3 11:11:13 2018

@author: Frank
"""

from MovieLens import MovieLens
from AutoRecAlgorithm import AutoRecAlgorithm
from surprise import NormalPredictor
from Evaluator import Evaluator
from surprise.model_selection import GridSearchCV

import random
import numpy as np

def LoadMovieLensData():
    ml = MovieLens()
    print("Loading movie ratings...")
    data = ml.loadMovieLensLatestSmall()
    print("\nComputing movie popularity ranks so we can measure novelty later...")
    rankings = ml.getPopularityRanks()
    return (ml, data, rankings)

np.random.seed(29)
random.seed(29)

# Load up common data set for the recommender algorithms
(ml, evaluationData, rankings) = LoadMovieLensData()

print("Searching for best parameters...")
param_grid = {'hiddenDim': [100, 200], 'learningRate': [0.1, 0.2]}
gs_ac = GridSearchCV(AutoRecAlgorithm, param_grid, measures=['rmse', 'mae'], cv=2)

gs_ac.fit(evaluationData)

# best RMSE score
print("Best RMSE score attained: ", gs_ac.best_score['rmse'])

# combination of parameters that gave the best RMSE score
print(gs_ac.best_params['rmse'])

# Construct an Evaluator to, you know, evaluate them
evaluator = Evaluator(evaluationData, rankings)

params = gs_ac.best_params['rmse']
AutoRectuned = AutoRecAlgorithm(hiddenDim = params['hiddenDim'], learningRate = params['learningRate'])
evaluator.AddAlgorithm(AutoRectuned, "AutoRec - Tuned")

#Autoencoder
AutoRecUntuned = AutoRecAlgorithm()
evaluator.AddAlgorithm(AutoRecUntuned, "AutoRec - Untuned")

# Just make random recommendations
Random = NormalPredictor()
evaluator.AddAlgorithm(Random, "Random")

# Fight!
evaluator.Evaluate(True)

evaluator.SampleTopNRecs(ml)
# Out:
# Loading movie ratings...
#
# Computing movie popularity ranks so we can measure novelty later...
# Searching for best parameters...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Best RMSE score attained:  1.906448756213003
# {'hiddenDim': 200, 'learningRate': 0.1}
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating  AutoRec - Tuned ...
# Evaluating accuracy...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Evaluating top-N with leave-one-out...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing hit-rate and rank metrics...
# Computing recommendations with full data set...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Analyzing coverage, diversity, and novelty...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Analysis complete.
# Evaluating  AutoRec - Untuned ...
# Evaluating accuracy...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Evaluating top-N with leave-one-out...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing hit-rate and rank metrics...
# Computing recommendations with full data set...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Analyzing coverage, diversity, and novelty...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Analysis complete.
# Evaluating  Random ...
# Evaluating accuracy...
# Evaluating top-N with leave-one-out...
# Computing hit-rate and rank metrics...
# Computing recommendations with full data set...
# Analyzing coverage, diversity, and novelty...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Analysis complete.
#
#
# Algorithm  RMSE       MAE        HR         cHR        ARHR       Coverage   Diversity  Novelty
# AutoRec - Tuned 1.9115     1.5555     0.0066     0.0066     0.0014     1.0000     0.0993     1031.8092
# AutoRec - Untuned 1.9996     1.6518     0.0033     0.0033     0.0008     1.0000     0.2826     1797.7241
# Random     1.4247     1.1382     0.0082     0.0082     0.0042     1.0000     0.0506     847.5872
#
# Legend:
#
# RMSE:      Root Mean Squared Error. Lower values mean better accuracy.
# MAE:       Mean Absolute Error. Lower values mean better accuracy.
# HR:        Hit Rate; how often we are able to recommend a left-out rating. Higher is better.
# cHR:       Cumulative Hit Rate; hit rate, confined to ratings above a certain threshold. Higher is better.
# ARHR:      Average Reciprocal Hit Rank - Hit rate that takes the ranking into account. Higher is better.
# Coverage:  Ratio of users for whom recommendations above a certain threshold exist. Higher is better.
# Diversity: 1-S, where S is the average similarity score between every possible pair of recommendations
#            for a given user. Higher means more diverse.
# Novelty:   Average popularity rank of recommended items. Higher means more novel.
#
# Using recommender  AutoRec - Tuned
#
# Building recommendation model...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing recommendations...
#
# We recommend:
# Toy Story (1995) 5
# She's the One (1996) 5
# Starship Troopers (1997) 5
# Labyrinth (1986) 5
# 13th Warrior, The (1999) 5
# Sister Act (1992) 5
# Shaft (1971) 5
# Lady and the Tramp (1955) 5
# Piranha (1978) 5
# Brazil (1985) 5
#
# Using recommender  AutoRec - Untuned
#
# Building recommendation model...
# Trained epoch  0
# Trained epoch  1
# Trained epoch  2
# Trained epoch  3
# Trained epoch  4
# Trained epoch  5
# Trained epoch  6
# Trained epoch  7
# Trained epoch  8
# Trained epoch  9
# Trained epoch  10
# Trained epoch  11
# Trained epoch  12
# Trained epoch  13
# Trained epoch  14
# Trained epoch  15
# Trained epoch  16
# Trained epoch  17
# Trained epoch  18
# Trained epoch  19
# Trained epoch  20
# Trained epoch  21
# Trained epoch  22
# Trained epoch  23
# Trained epoch  24
# Trained epoch  25
# Trained epoch  26
# Trained epoch  27
# Trained epoch  28
# Trained epoch  29
# Trained epoch  30
# Trained epoch  31
# Trained epoch  32
# Trained epoch  33
# Trained epoch  34
# Trained epoch  35
# Trained epoch  36
# Trained epoch  37
# Trained epoch  38
# Trained epoch  39
# Trained epoch  40
# Trained epoch  41
# Trained epoch  42
# Trained epoch  43
# Trained epoch  44
# Trained epoch  45
# Trained epoch  46
# Trained epoch  47
# Trained epoch  48
# Trained epoch  49
# Trained epoch  50
# Trained epoch  51
# Trained epoch  52
# Trained epoch  53
# Trained epoch  54
# Trained epoch  55
# Trained epoch  56
# Trained epoch  57
# Trained epoch  58
# Trained epoch  59
# Trained epoch  60
# Trained epoch  61
# Trained epoch  62
# Trained epoch  63
# Trained epoch  64
# Trained epoch  65
# Trained epoch  66
# Trained epoch  67
# Trained epoch  68
# Trained epoch  69
# Trained epoch  70
# Trained epoch  71
# Trained epoch  72
# Trained epoch  73
# Trained epoch  74
# Trained epoch  75
# Trained epoch  76
# Trained epoch  77
# Trained epoch  78
# Trained epoch  79
# Trained epoch  80
# Trained epoch  81
# Trained epoch  82
# Trained epoch  83
# Trained epoch  84
# Trained epoch  85
# Trained epoch  86
# Trained epoch  87
# Trained epoch  88
# Trained epoch  89
# Trained epoch  90
# Trained epoch  91
# Trained epoch  92
# Trained epoch  93
# Trained epoch  94
# Trained epoch  95
# Trained epoch  96
# Trained epoch  97
# Trained epoch  98
# Trained epoch  99
# Processing user  0
# Processing user  50
# Processing user  100
# Processing user  150
# Processing user  200
# Processing user  250
# Processing user  300
# Processing user  350
# Processing user  400
# Processing user  450
# Processing user  500
# Processing user  550
# Processing user  600
# Computing recommendations...
#
# We recommend:
# Quiz Show (1994) 5
# Pretty Woman (1990) 5
# Man Without a Face, The (1993) 5
# Kung Fu Hustle (Gong fu) (2004) 5
# Daylight (1996) 5
# Boy Who Could Fly, The (1986) 5
# Forces of Nature (1999) 5
# Save the Last Dance (2001) 5
# Daredevil (2003) 5
# Doctor, The (1991) 5
#
# Using recommender  Random
#
# Building recommendation model...
# Computing recommendations...
#
# We recommend:
# Seven (a.k.a. Se7en) (1995) 5
# Sword in the Stone, The (1963) 5
# Swingers (1996) 5
# Alien (1979) 5
# Blues Brothers, The (1980) 5
# Quiet Man, The (1952) 5
# Shining, The (1980) 5
# Labyrinth (1986) 5
# Lethal Weapon (1987) 5
# Charlotte's Web (1973) 5
